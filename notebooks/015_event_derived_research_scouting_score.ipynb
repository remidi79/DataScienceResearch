# %% [markdown]
# # Experiment 015 — Event-Derived Research Scouting Score Prototype

# %% [markdown]
# Research-only. Event-derived. Not provider-direct. Not production-ready.

# %%
import pandas as pd
scores = pd.read_csv('outputs/tables/015_event_derived_research_scouting_scores.csv')
scores.head()

# %%
validation = pd.read_csv('outputs/tables/015_validation_results.csv')
validation
