# %% [markdown]
# # Experiment 004 — Role-Specific Weight Estimation & Prototype Score Formula

# %% [markdown]
# ## 1. Objective
#
# Estimate role-specific prototype metric and dimension weights. This is not a final production score.

# %% [markdown]
# ## 2. Football hypothesis
#
# Different roles require independent weighting logic, and every weight must be traceable to data evidence.

# %% [markdown]
# ## 3. Dataset
#
# Data root: `/home/platform/DataPlatform/tmp/master_data_warehouse` plus Experiment 002/003 tables.

# %% [markdown]
# ## 4. Feature engineering
#
# Build normalized feature matrix with selected Experiment 003 normalization methods, direction registry, percentiles, and benchmark bands.

# %% [markdown]
# ## 5. Exploratory Data Analysis
#
# Inspect prototype feature, weight, dimension, and score tables.

# %% [markdown]
# ## 6. Statistical Analysis
#
# Equal, PCA, variance, stability, entropy, bootstrap, and shrunk ensemble candidate weights are compared.

# %% [markdown]
# ## 7. Machine Learning
#
# No predictive model is trained. PCA/MI/bootstrap are used only as unsupervised weighting evidence.

# %% [markdown]
# ## 8. Explainability
#
# Metric and dimension weights include method components, shrinkage, caps, confidence, and warning flags.

# %% [markdown]
# ## 9. Validation
#
# Ad-hoc verification checks tables, reports, figures, sums, score ranges, role exclusions, and no Experiment 005 artefacts.

# %% [markdown]
# ## 10. Conclusions
#
# Prototype scores are research artefacts for Experiment 005 validation only.

# %% [markdown]
# ## 11. Next Experiments
#
# Experiment 005 should validate, calibrate, and compare scores across robustness checks.

# %% [markdown]
# ## Reproduce
#
# ```bash
# uv run python experiments/004_role_specific_weight_estimation.py --data-root /home/platform/DataPlatform/tmp/master_data_warehouse
# ```

# %%
import pandas as pd
pd.read_csv('outputs/tables/004_metric_weight_decisions.csv').head()

# %%
pd.read_csv('outputs/tables/004_dimension_weight_decisions.csv').head()

# %%
pd.read_csv('outputs/tables/004_prototype_role_scores.csv').head()
