# %% [markdown]
# # Experiment 006 — Temporal, Match-Level & Cross-Competition Validation

# %% [markdown]
# ## 1. Objective
#
# Reproducible Experiment 006 artefact.

# %% [markdown]
# ## 2. Previous Experiments Summary
#
# Reproducible Experiment 006 artefact.

# %% [markdown]
# ## 3. Dataset
#
# Reproducible Experiment 006 artefact.

# %% [markdown]
# ## 4. Match-Level Score Materialization
#
# Reproducible Experiment 006 artefact.

# %% [markdown]
# ## 5. Season-Split Histories
#
# Reproducible Experiment 006 artefact.

# %% [markdown]
# ## 6. Temporal Stability
#
# Reproducible Experiment 006 artefact.

# %% [markdown]
# ## 7. Leave-One-Season-Out Validation
#
# Reproducible Experiment 006 artefact.

# %% [markdown]
# ## 8. Leave-One-Competition-Out Validation
#
# Reproducible Experiment 006 artefact.

# %% [markdown]
# ## 9. Population Drift
#
# Reproducible Experiment 006 artefact.

# %% [markdown]
# ## 10. Team Context Sensitivity
#
# Reproducible Experiment 006 artefact.

# %% [markdown]
# ## 11. Minutes Threshold Sensitivity
#
# Reproducible Experiment 006 artefact.

# %% [markdown]
# ## 12. Calibration Curves
#
# Reproducible Experiment 006 artefact.

# %% [markdown]
# ## 13. Football Expert Review Workflow
#
# Reproducible Experiment 006 artefact.

# %% [markdown]
# ## 14. Production-Candidate Gate
#
# Reproducible Experiment 006 artefact.

# %% [markdown]
# ## 15. Conclusions
#
# Reproducible Experiment 006 artefact.

# %% [markdown]
# ## 16. Next Experiments
#
# Reproducible Experiment 006 artefact.

# %%
import pandas as pd
pd.read_csv('outputs/tables/006_match_level_score_history.csv').head()

# %%
pd.read_csv('outputs/tables/006_production_candidate_gate.csv').head()
