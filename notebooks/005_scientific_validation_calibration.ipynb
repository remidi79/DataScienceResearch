# %% [markdown]
# # Experiment 005 — Scientific Validation & Calibration of the Football Score Engine

# %% [markdown]
# ## 1. Objective
#
# Reproducible validation artefact.

# %% [markdown]
# ## 2. Previous Experiments Summary
#
# Reproducible validation artefact.

# %% [markdown]
# ## 3. Dataset
#
# Reproducible validation artefact.

# %% [markdown]
# ## 4. Bootstrap Validation
#
# Reproducible validation artefact.

# %% [markdown]
# ## 5. Reliability Analysis
#
# Reproducible validation artefact.

# %% [markdown]
# ## 6. Rank Stability
#
# Reproducible validation artefact.

# %% [markdown]
# ## 7. Sensitivity Analysis
#
# Reproducible validation artefact.

# %% [markdown]
# ## 8. Score Independence
#
# Reproducible validation artefact.

# %% [markdown]
# ## 9. Football Consistency Review
#
# Reproducible validation artefact.

# %% [markdown]
# ## 10. Explainability
#
# Reproducible validation artefact.

# %% [markdown]
# ## 11. Production Readiness
#
# Reproducible validation artefact.

# %% [markdown]
# ## 12. Conclusions
#
# Reproducible validation artefact.

# %% [markdown]
# ## 13. Next Experiments
#
# Reproducible validation artefact.

# %%
import pandas as pd
pd.read_csv('outputs/tables/bootstrap_statistics.csv').head()

# %%
pd.read_csv('outputs/tables/production_readiness.csv').head()
